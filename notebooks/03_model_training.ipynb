# %% [markdown]
# # Step 3: Model Training (XGBoost)
# In this notebook, we take the final 14-day aggregated `.csv`, handle imbalanced training with SMOTE (or class weights), train our predictive model, and output the risk scores plus feature importance so we can explain *why* the model predicts churn.
