# %% [markdown]
# # Step 2: Feature Engineering & Aggregation (The 14-Day Window)
# In this notebook, we take the clean data from `02_processed/`, calculate the exact 14-day cutoff window before the customer's renewal, filter all calls/emails to that window, and aggregate the features back onto the main billings dataset so it is ready for Machine Learning.
